# %%
import pandas as pd

# %%
df7 = pd.read_csv("202207-citibike-tripdata.csv")
df7.head()
# Out:
# C:\Users\aloun\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             ride_id  rideable_type           started_at             ended_at  \
# 0  C09E4093905089BD   classic_bike  2022-07-23 11:34:57  2022-07-23 11:45:08
# 1  374630DB5822C392  electric_bike  2022-07-29 18:19:08  2022-07-29 18:26:50
# 2  4F73CA25880A1215  electric_bike  2022-07-16 16:30:58  2022-07-16 17:39:18
# 3  ECD6EE19C0CC1D31  electric_bike  2022-07-17 17:35:57  2022-07-17 18:03:36
# 4  44D0987673B9997D   classic_bike  2022-07-11 07:56:29  2022-07-11 07:59:15
#
#       start_station_name start_station_id               end_station_name  \
# 0  Melrose St & Broadway          4801.04          Myrtle Ave & Grove St
# 1        E 68 St & 3 Ave          6896.16             E 85 St & York Ave
# ...

# %%
df1 = pd.read_csv("202301-citibike-tripdata.csv")
df1.head()
# Out:
# C:\Users\aloun\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             ride_id  rideable_type           started_at             ended_at  \
# 0  4A86C1475DCCADA0   classic_bike  2023-01-26 10:53:44  2023-01-26 11:05:17
# 1  AE02E1FF7E264874   classic_bike  2023-01-04 11:51:54  2023-01-04 12:07:09
# 2  D3F9A2A71AD244C6   classic_bike  2023-01-04 17:26:48  2023-01-04 17:43:29
# 3  3D48C6F33AFEF329   classic_bike  2023-01-04 08:31:11  2023-01-04 08:42:12
# 4  4865926C3D97BA01  electric_bike  2023-01-03 22:15:34  2023-01-03 22:30:35
#
#                    start_station_name start_station_id  \
# 0               E 53 St & Madison Ave          6659.03
# 1               Halsey St & Ralph Ave          4334.02
# 2                 Bank St & Hudson St          5922.08
# ...

# %%
df3 = pd.read_csv("202303-citibike-tripdata.csv")
df3.head()
# Out:
# C:\Users\aloun\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             ride_id rideable_type           started_at             ended_at  \
# 0  EAB9FFEAB7BDBAF2  classic_bike  2023-03-15 18:11:59  2023-03-15 18:18:38
# 1  B57211E2408E604F  classic_bike  2023-03-18 21:05:59  2023-03-18 21:10:51
# 2  9411DD44FB7406A9  classic_bike  2023-03-16 10:16:15  2023-03-16 10:24:27
# 3  DC2D4F90D746F435  classic_bike  2023-03-01 06:55:20  2023-03-01 07:05:44
# 4  63874304EFBD61EE  classic_bike  2023-03-02 23:21:02  2023-03-02 23:42:19
#
#         start_station_name  start_station_id                end_station_name  \
# 0          6 Ave & W 33 St           6364.07                 9 Ave & W 22 St
# 1          6 Ave & W 33 St           6364.07                 W 35 St & 9 Ave
# ...

# %%
df4 = pd.read_csv("202304-citibike-tripdata.csv")
df4.head()
# Out:
# C:\Users\aloun\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             ride_id  rideable_type           started_at             ended_at  \
# 0  159C90AB46D5631B   classic_bike  2023-04-01 17:24:06  2023-04-01 17:46:10
# 1  4349D44670885CED  electric_bike  2023-04-13 15:09:12  2023-04-13 15:16:11
# 2  55EB4E8AF45439D2  electric_bike  2023-04-28 15:17:00  2023-04-28 15:26:09
# 3  3133FC58AA938D08   classic_bike  2023-04-23 16:18:49  2023-04-23 17:10:50
# 4  BF2DD897668DA1AC   classic_bike  2023-04-21 15:42:08  2023-04-21 15:47:04
#
#       start_station_name start_station_id           end_station_name  \
# 0    Hoyt St & Warren St          4330.09  Washington St & Laight St
# 1        E 25 St & 2 Ave          6046.02            E 47 St & 2 Ave
# ...

# %%
df5 = pd.read_csv("202305-citibike-tripdata_original.csv")
df5
# Out:
# C:\Users\aloun\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                   ride_id  rideable_type           started_at  \
# 0        176B188F3289F37B   classic_bike  2023-05-23 19:22:53
# 1        BB6957A02501C686   classic_bike  2023-05-27 08:49:55
# 2        C67567E1DAFB9F2C   classic_bike  2023-05-12 20:19:58
# 3        89DDFCEAE05D043A  electric_bike  2023-05-03 07:59:13
# 4        63B1D5A7A2316252   classic_bike  2023-05-13 10:23:52
# ...                   ...            ...                  ...
# 3580761  BA28157F10FA9C78   classic_bike  2023-05-11 17:37:54
# 3580762  5FD57F3ED53FDBEB   classic_bike  2023-05-21 12:36:04
# 3580763  30CC35A9A433B701   classic_bike  2023-05-08 09:37:54
# 3580764  2968C17CC49A7187   classic_bike  2023-05-27 19:55:19
# ...

# %%
new_df = pd.concat([df7,df1,df5])
new_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  C09E4093905089BD   classic_bike  2022-07-23 11:34:57  2022-07-23 11:45:08
# 1  374630DB5822C392  electric_bike  2022-07-29 18:19:08  2022-07-29 18:26:50
# 2  4F73CA25880A1215  electric_bike  2022-07-16 16:30:58  2022-07-16 17:39:18
# 3  ECD6EE19C0CC1D31  electric_bike  2022-07-17 17:35:57  2022-07-17 18:03:36
# 4  44D0987673B9997D   classic_bike  2022-07-11 07:56:29  2022-07-11 07:59:15
#
#       start_station_name start_station_id               end_station_name  \
# 0  Melrose St & Broadway          4801.04          Myrtle Ave & Grove St
# 1        E 68 St & 3 Ave          6896.16             E 85 St & York Ave
# 2       W 37 St & 10 Ave          6611.02  Knickerbocker Ave & Cooper St
# 3       W 37 St & 10 Ave          6611.02              6 Ave & Broome St
# 4        E 68 St & 3 Ave          6896.16          E 66 St & Madison Ave
#
# ...

# %%
new_df.to_csv("22-23-7-1-5-citibike-tripdata.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2680\797311811.py in <module>
# ----> 1 new_df.to_csv("22-23-7-1-5-citibike-tripdata.csv")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     202             )
#     203
# --> 204             self._save()
#     205
#     206         finally:
#
# ...

# %%
new_df = pd.concat([df1,df5])
new_df.head()

# %%
new_df.to_csv("23-1-5-citibike-tripdata.csv")

# %%
df5_cleaned = df5.dropna(how="any")
df5_cleaned
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        176B188F3289F37B   classic_bike  2023-05-23 19:22:53
# 1        BB6957A02501C686   classic_bike  2023-05-27 08:49:55
# 2        C67567E1DAFB9F2C   classic_bike  2023-05-12 20:19:58
# 3        89DDFCEAE05D043A  electric_bike  2023-05-03 07:59:13
# 4        63B1D5A7A2316252   classic_bike  2023-05-13 10:23:52
# ...                   ...            ...                  ...
# 3580761  BA28157F10FA9C78   classic_bike  2023-05-11 17:37:54
# 3580762  5FD57F3ED53FDBEB   classic_bike  2023-05-21 12:36:04
# 3580763  30CC35A9A433B701   classic_bike  2023-05-08 09:37:54
# 3580764  2968C17CC49A7187   classic_bike  2023-05-27 19:55:19
# 3580765  CD9203C8D4896BA1   classic_bike  2023-05-23 19:08:47
#
#                     ended_at        start_station_name start_station_id  \
# 0        2023-05-23 19:35:23        E 50 St & Park Ave          6659.10
# 1        2023-05-27 08:57:42  Flatbush Ave & Ocean Ave          3704.04
# ...

# %%
df5_cleaned.to_csv("202305-citibike-tripdata.csv")
